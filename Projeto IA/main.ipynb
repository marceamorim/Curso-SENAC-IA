# %%
import pandas as pd

# %%
df=pd.read_excel('database.xlsx')

df.head(10)
# Out:
#   id_produto      categoria             produto      variante unidade_venda  \
# 0       P001  Mini Cupcakes        Mini Cupcake   Tradicional       unidade
# 1       P002  Mini Cupcakes        Mini Cupcake      Especial       unidade
# 2       P003       Cupcakes             Cupcake   Tradicional       unidade
# 3       P004       Cupcakes             Cupcake      Especial       unidade
# 4       P005       Docinhos  Doces Tradicionais   50 unidades        pacote
# 5       P006       Docinhos  Doces Tradicionais  100 unidades        pacote
# 6       P007       Docinhos      Doces Gourmets   50 unidades        pacote
# 7       P008       Docinhos      Doces Gourmets  100 unidades        pacote
# 8       P009       Docinhos     Doces Especiais   50 unidades        pacote
# 9       P010       Docinhos     Doces Especiais  100 unidades        pacote
#
#    quantidade_minima limite_sabores  preco unidade_preco  \
# 0               12.0  até 2 sabores      4          cada
# ...

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.strip()

df
# Out:
#    id_produto                categoria                         produto  \
# 0        P001            Mini Cupcakes                    Mini Cupcake
# 1        P002            Mini Cupcakes                    Mini Cupcake
# 2        P003                 Cupcakes                         Cupcake
# 3        P004                 Cupcakes                         Cupcake
# 4        P005                 Docinhos              Doces Tradicionais
# 5        P006                 Docinhos              Doces Tradicionais
# 6        P007                 Docinhos                  Doces Gourmets
# 7        P008                 Docinhos                  Doces Gourmets
# 8        P009                 Docinhos                 Doces Especiais
# 9        P010                 Docinhos                 Doces Especiais
# 10       P011  Casquinhas de chocolate                       Casquinha
# 11       P012  Casquinhas de chocolate                       Casquinha
# ...
